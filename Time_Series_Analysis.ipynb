# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment</b>
#
# Hi, Jasper! I am a reviewer on this project.
#
#
# Before we start, I want to pay your attention to the color marking:
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ✔️</b>
#
# Great solutions and ideas that can and should be used in the future are in green comments.
# </div>
#
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ⚠️</b>
#
# Yellow color indicates what should be optimized. This is not necessary, but it will be great if you make changes to this project.
# </div>
#
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# Issues that need to be corrected to get right results are indicated in red comments. Note that the project cannot be accepted until these issues are resolved.
# </div>
#
# <hr>
#
# **Please, use some color other than those listed to highlight answers to my comments.**
# I would also ask you **not to change, move or delete my comments** so that it would be easier for me to navigate during the next review.
#
# In addition, my comments are defined as headings.
# They can mess up the content; however, they are convenient, since you can immediately go to them. I will remove the headings from my comments in the next review.
#
#
#
# <hr>
#
# <font color='dodgerblue'>**A few words about the project:**</font> thank you very much for submitting the project! You did a fantastic job here, and I hope you enjoyed this topic. You have successfully trained several models and analyzed time series, which is great! However, there're a couple of issues that need your attention. Would you take a look at my comments?
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 2</b>
#
# Thank you for updates! My new comments have digit 2.
#
#
# I do not have any questions, so I can accept the project now. Thank you again for such an excellent job here. Congratulations and good luck!
#
# </div>

# %% [markdown]
# # Project description
#
# Sweet Lift Taxi company has collected historical data on taxi orders at airports. To attract more drivers during peak hours, we need to predict the amount of taxi orders for the next hour. Build a model for such a prediction.
#
# The RMSE metric on the test set should not be more than 48.
#
# ## Project instructions
#
# 1. Download the data and resample it by one hour.
# 2. Analyze the data.
# 3. Train different models with different hyperparameters. The test sample should be 10% of the initial dataset.
# 4. Test the data using the test sample and provide a conclusion.
#
# ## Data description
#
# The data is stored in file `taxi.csv`. The number of orders is in the '*num_orders*' column.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment </h2>
#
# Good introduction!
#
# </div>

# %% [markdown]
# ## Preparation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
import time

# %%
df = pd.read_csv("/datasets/taxi.csv", index_col=[0], parse_dates=[0])
df
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32
# ...                         ...
# 2018-08-31 23:10:00          32
# 2018-08-31 23:20:00          24
# 2018-08-31 23:30:00          27
# 2018-08-31 23:40:00          39
# 2018-08-31 23:50:00          53
#
# [26496 rows x 1 columns]

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>  Reviewer's comment </b>
#
#
# You can read data in one cell and put imports in another.
#
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# Good!
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Student's comment </h2>
#
# updated.
#
# </div>

# %%
#Check for duplicates
df.duplicated().any()
# Out:
# True

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>  Reviewer's comment </h2>
#
#
# Should we do anything with them?
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Student's comment </h2>
#
# In this case, no. What I should have done was to check duplicate indexes. Updated below.
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# That is why conclusions are important :)
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# You do not need to check index, since these values will not be duplicated.
# </div>

# %%
df.index.duplicated().any()
# Out:
# False

# %%
#Check for NaNs
df.isna().any()
# Out:
# num_orders    False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 1.4 MB

# %%
df.sort_index(inplace=True)
print(df.index.is_monotonic)
df = df.resample("1H").sum()
# Out:
# True

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>  Reviewer's comment </b>
#
#
# Please do not forget about the intermediate conclusions.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Student's comment </h2>
#
# Updated below.
#
# </div>

# %% [markdown]
# There are no duplicate indexes entries in the dataset. There are also no NaNs in the dataset. And the indexes are in chronological order.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# Well done.
# </div>

# %% [markdown]
# ## Analysis

# %%
df.plot()

# Add title and labels
plt.title('Number of Orders per Day')
plt.xlabel('Date')
plt.ylabel('Number of Orders')

# Show the plot
plt.show()

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  </b>
#
#
# Good job! Please don't forget to add titles and axes labels so that a reader can easily understand what's going on here. It is also a good habit to leave some comments under each graph. We do our job for a client, and he or she may not understand the graph at all. That's why we need titels, labels and comments :)
#
#
# You can use the following piece of code:
# </div>
#
# ```python
#
# plt.title('Title')
# plt.xlabel('X')
# plt.ylabel('Y')
#
# ```
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# Looks great!
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Student's comment </h2>
#
# Updated above.
#
# </div>

# %%
decomposed = seasonal_decompose(df)
decomposed.plot()

# %%
# Extract the seasonal component
seasonal = decomposed.seasonal

# Define the date range you want to zoom in on
start_date = '2018-07-01'
end_date = '2018-07-03'

# Slice the seasonal component
seasonal_zoomed = seasonal[start_date:end_date]

# %%
# Plot the zoomed seasonal component
plt.figure(figsize=(10, 4))
plt.plot(seasonal_zoomed)
plt.title('Seasonal Component (Zoomed In)')
plt.xlabel('Date')
plt.ylabel('Seasonality')
plt.show()

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment</h2>
#
# `seasonal_decompose` is a great method, well done!
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# You can also choose some interval to analyze seasonality. For instance, we may have an intraday seasonality, which makes sense in such dataset.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  </b>
#
#
# Please add a conclusion here. What can be inferred from these results? Is there any trend?
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Student's comment </h2>
#
# Updated below.
#
# </div>

# %% [markdown]
# From the decompose, we can see that the trend is increasing slowly overall. There is a intraday seasonality where it peaks at midnight of each day and dips at 6 am of each day.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# Very good!
# </div>

# %% [markdown]
# ## Training AND Testing

# %%
# Make features
def make_features(df, max_lag, rolling_mean_size):
    df['month'] = df.index.month
    df['day'] = df.index.day
    df['dayofweek'] = df.index.dayofweek

    for lag in range(1, max_lag + 1):
        df['lag_{}'.format(lag)] = df['num_orders'].shift(lag)

    
    df['rolling_mean'] = (
        df['num_orders'].shift().rolling(rolling_mean_size).mean()
    )
make_features(df, 24, 7)

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment </h2>
#
# Correct. Sometimes we can notice autocorrelation in time series. It means that the current value of the series depends on the previous values. Including so-called lag components allows machine learning models, such as linear regression, to take this dependency into account.
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# - However, will year be helpful given we have only one year in the data? :) This feature will not provide any useful information for the model and can lead to redundancy and increased computation time.
#
#
#
# - You can also add rolling mean. </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# Correct.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Student's comment </h2>
#
# Updated above. Removed year and added rolling mean size.
#
# </div>

# %%
df
# Out:
#                      num_orders  month  day  dayofweek  lag_1  lag_2  lag_3  \
# datetime
# 2018-03-01 00:00:00         124      3    1          3    NaN    NaN    NaN
# 2018-03-01 01:00:00          85      3    1          3  124.0    NaN    NaN
# 2018-03-01 02:00:00          71      3    1          3   85.0  124.0    NaN
# 2018-03-01 03:00:00          66      3    1          3   71.0   85.0  124.0
# 2018-03-01 04:00:00          43      3    1          3   66.0   71.0   85.0
# ...                         ...    ...  ...        ...    ...    ...    ...
# 2018-08-31 19:00:00         136      8   31          4  207.0  217.0  197.0
# 2018-08-31 20:00:00         154      8   31          4  136.0  207.0  217.0
# 2018-08-31 21:00:00         159      8   31          4  154.0  136.0  207.0
# 2018-08-31 22:00:00         223      8   31          4  159.0  154.0  136.0
# 2018-08-31 23:00:00         205      8   31          4  223.0  159.0  154.0
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

train, temp = train_test_split(df, shuffle=False, test_size=0.2)
train = train.dropna()
valid, test = train_test_split(temp, shuffle=False, test_size=0.5)

features_train = train.drop(columns='num_orders')
target_train = train['num_orders']

features_valid = valid.drop(columns='num_orders')
target_valid = valid['num_orders']

features_test = test.drop(columns='num_orders')
target_test = test['num_orders']

# features_train = pd.concat([features_train, features_valid], axis=0)
# target_train = pd.concat([target_train, target_valid], axis=0)

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment </h2>
#
# Correct. Working with time series, we should not shuffle the data.
#
# </div>
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Isn't it easier to split the data into two parts if you want to have two? By the way, it may still be useful to have three subsets.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# I see the updates, good.
# </div>

# %%
# Train Linear Regression Model
lr_model = LinearRegression()
start_time = time.time()
lr_model.fit(features_train, target_train)
lr_fit_time = time.time() - start_time
predictions_valid = lr_model.predict(features_valid)
predictions_test = lr_model.predict(features_test)

# Score error
print("RSME for the valid set:", mean_squared_error(target_valid, predictions_valid, squared=False))
print("RSME for the test set: ", mean_squared_error(target_test, predictions_test, squared=False))
print(f"LR Fit Time: {lr_fit_time}")
# Out:
# RSME for the valid set: 34.06757037306073
# RSME for the test set:  46.114078853086156
# LR Fit Time: 0.021550893783569336

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# In the previous cell, you combine train and validation subset `features_train = pd.concat([features_train, features_valid], axis=0)`. Here, however, you train data on this combined subset (which includes validation) and then estimate RMSE on validation (`features_valid`).
#
#
# Was that done on purpose? I believe it was, since you estimate RMSE on test subset as well, but you can use the whole training subset instead of the validation part. Would you please clarify this thing?
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# By the way, `squared` parameter is deprecated, so it may not work with the latest sklearn versions.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Student's comment </h2>
#
#  - In the beginning, I separated into 3 subsets: training, validation, and test. I trained on the training set. And I predicted on the valid set. However, I kept getting results above RSME of 48. And after checking discord for some help, I saw on one of the threads that we should combine the training and validation datasets for fitting. <br>
#
# - Instead of rewriting my code, I just combined the training and validation set using concat. I trained on the training and validation set. And I predicted on validation part of the dataset. Perhaps I should also predict on the training + validation set? <br>
#
#
# - In the end it made sense to use a larger dataset as it would capture the increasing upward trend. <br>
#
#
# - However, I will go back to using 3 subsets. By adding rolling mean, my predictions got better.
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# > I saw on one of the threads that we should combine the training and validation datasets for fitting
#
#
# Yes, we may need that before you conduct the final test :) Here, however, we are trying different models and tuning hyperparameters, so all we need is to use training subset for training and validation subset for RMSE estimation.
#
#
# When we choose the best model, we train it on a combined data and use test subset to estimate RMSE once again.
# </div>

# %%
pred_valid_df = pd.DataFrame(predictions_valid, index=target_valid.index)
pred_valid_df.rename(columns={0: 'Predictions'}, inplace=True)

pred_test_df = pd.DataFrame(predictions_test, index=target_test.index)
pred_test_df.rename(columns={0: 'Predictions'}, inplace=True)

# Plot the training predictions and actual values
ax1 = pred_valid_df.plot(label='Predictions')
target_valid.plot(ax=ax1, label='Actual')

# Display the legend for the first plot
ax1.legend()

# Plot the testing predictions and actual values
ax2 = pred_test_df.plot(label='Predictions')
target_test.plot(ax=ax2, label='Actual')

# Display the legend for the second plot
ax2.legend()

# Display the plots
plt.show()

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Would you add a conclusion here?
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Student's comment </h2>
#
# updated below.
#
# </div>

# %% [markdown]
# The Linear Regression model performed well compared to the other models in terms of RMSE and speed.
# - The RSME for the valid set is 34.07.
# - The RSME for the test set is  46.11.
# - LR Fit Time: 0.026882171630859375

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# Good!
#
# </div>

# %%
# Train Decision Tree Model
dt_model = DecisionTreeRegressor()
start_time = time.time()
dt_model.fit(features_train, target_train)
dt_fit_time = time.time() - start_time
predictions_valid = dt_model.predict(features_valid)
predictions_test = dt_model.predict(features_test)

# Score error
print("RSME for the valid set:", mean_squared_error(target_valid, predictions_valid, squared=False))
print("RSME for the test set: ", mean_squared_error(target_test, predictions_test, squared=False))
print(f"DT Fit Time: {dt_fit_time}")
# Out:
# RSME for the valid set: 45.89243275982855
# RSME for the test set:  62.32141907898198
# DT Fit Time: 0.11776065826416016

# %%
pred_valid_df = pd.DataFrame(predictions_valid, index=target_valid.index)
pred_valid_df.rename(columns={0: 'Predictions'}, inplace=True)

pred_test_df = pd.DataFrame(predictions_test, index=target_test.index)
pred_test_df.rename(columns={0: 'Predictions'}, inplace=True)

# Plot the training predictions and actual values
ax1 = pred_valid_df.plot(label='Predictions')
target_valid.plot(ax=ax1, label='Actual')

# Display the legend for the first plot
ax1.legend()

# Plot the testing predictions and actual values
ax2 = pred_test_df.plot(label='Predictions')
target_test.plot(ax=ax2, label='Actual')

# Display the legend for the second plot
ax2.legend()

# Display the plots
plt.show()

# %%
best_model = None
best_result = 10000
best_est = 0
best_depth = 0
for est in range(70, 111, 10):
    for depth in range (80, 91):
        rf_model = RandomForestRegressor(random_state=12345, n_estimators=est, max_depth=depth)# initialize model constructor with parameters random_state=12345 and n_estimators=est
        rf_model.fit(features_train, target_train) # train model on training set
        predictions_valid = rf_model.predict(features_valid) # get model predictions on validation set
        result = mean_squared_error(target_valid, predictions_valid, squared=False) # calculate RMSE on validation set
        if result < best_result:
            best_model = rf_model
            best_result = result
            best_est = est
            best_depth = depth

print("RMSE of the best model on the validation set:", best_result, "n_estimators:", best_est, "best_depth:", depth)
# Out:
# RMSE of the best model on the validation set: 32.773732391528824 n_estimators: 110 best_depth: 90

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Here, however, validation should not intersect with the train subset. We just should not tune hyperparameters using the subset that takes part in the training process.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# Correct!
# </div>

# %%
# Train Random Forest Regressor Model
rf_model = RandomForestRegressor(random_state=12345, max_depth=best_depth, n_estimators=best_est)
start_time = time.time()
rf_model.fit(features_train, target_train)
rf_fit_time = time.time() - start_time
predictions_valid = rf_model.predict(features_valid)
predictions_test = rf_model.predict(features_test)

# Score error
print("RSME for the valid set:", mean_squared_error(target_valid, predictions_valid, squared=False))
print("RSME for the test set: ", mean_squared_error(target_test, predictions_test, squared=False))
print(f"RF Fit Time: {rf_fit_time}")
# Out:
# RSME for the valid set: 32.773732391528824
# RSME for the test set:  49.577953089621886
# RF Fit Time: 8.105842590332031

# %%
pred_valid_df = pd.DataFrame(predictions_valid, index=target_valid.index)
pred_valid_df.rename(columns={0: 'Predictions'}, inplace=True)

pred_test_df = pd.DataFrame(predictions_test, index=target_test.index)
pred_test_df.rename(columns={0: 'Predictions'}, inplace=True)

# Plot the training predictions and actual values
ax1 = pred_valid_df.plot(label='Predictions')
target_valid.plot(ax=ax1, label='Actual')

# Display the legend for the first plot
ax1.legend()

# Plot the testing predictions and actual values
ax2 = pred_test_df.plot(label='Predictions')
target_test.plot(ax=ax2, label='Actual')

# Display the legend for the second plot
ax2.legend()

# Display the plots
plt.show()

# %%
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit

# Define the parameter grid
param_grid = {
    'num_leaves': [10, 12, 14],
    'n_estimators': [100, 110, 120],
    'learning_rate': [0.1, 0.12],
}

lgb_model = lgb.LGBMRegressor()

# Use TimeSeriesSplit for cross-validation
tscv = TimeSeriesSplit(n_splits=4)

lgb_grid_search = GridSearchCV(estimator=lgb_model, param_grid=param_grid, cv=tscv, scoring='neg_mean_squared_error', verbose=1, n_jobs=-1)

lgb_grid_search.fit(features_train, target_train)

print("Best parameters found: ", lgb_grid_search.best_params_)
# Out:
# Fitting 4 folds for each of 18 candidates, totalling 72 fits
# Best parameters found:  {'learning_rate': 0.1, 'n_estimators': 100, 'num_leaves': 10}

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# When we work with time series, we have to remember about the correct order in the data. To ensure that the training data always precedes the test data in time, we have to employ the `TimeSeriesSplit` class, a cross-validator for time series. Just use it as `cv` parameter value.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# It is correct now, well done!
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Student's comment </h2>
#
# Updated above.
#
# </div>

# %%
# Get the best estimator from the grid search
lgb_best_model = lgb_grid_search.best_estimator_

start_time = time.time()
lgb_best_model.fit(features_train, target_train)
lgb_fit_time = time.time() - start_time

# Predict on the valid set
lgb_target_predicted_valid = lgb_best_model.predict(features_valid)
# Calculate RMSE
rmse_valid = mean_squared_error(target_valid, lgb_target_predicted_valid, squared=False)

# Predict on the test set
lgb_target_predicted_test = lgb_best_model.predict(features_test)
# Calculate RMSE
rmse_test = mean_squared_error(target_test, lgb_target_predicted_test, squared=False)

print(f"LGB RMSE Valid score: {rmse_valid}")
print(f"LGB RMSE Test score: {rmse_test}")
print(f"LGB Fit Time: {lgb_fit_time}")
# Out:
# LGB RMSE Valid score: 33.11786131012929
# LGB RMSE Test score: 52.21167010545966
# LGB Fit Time: 0.28397274017333984

# %%
pred_valid_df = pd.DataFrame(lgb_target_predicted_valid, index=target_valid.index)
pred_valid_df.rename(columns={0: 'Predictions'}, inplace=True)

pred_test_df = pd.DataFrame(lgb_target_predicted_test, index=target_test.index)
pred_test_df.rename(columns={0: 'Predictions'}, inplace=True)

# Plot the training predictions and actual values
ax1 = pred_valid_df.plot(label='Predictions')
target_valid.plot(ax=ax1, label='Actual')

# Display the legend for the first plot
ax1.legend()

# Plot the testing predictions and actual values
ax2 = pred_test_df.plot(label='Predictions')
target_test.plot(ax=ax2, label='Actual')

# Display the legend for the second plot
ax2.legend()

# Display the plots
plt.show()

# %%
import xgboost as xgb

# Instantiate the model
xgb_reg = xgb.XGBRegressor()

# Define the parameter grid
xgb_param_grid = {
    'max_depth': [2, 3, 4],
    'n_estimators': [45, 50, 55],
    'learning_rate': [0.10, 0.12]
}


# Use TimeSeriesSplit for cross-validation
tscv = TimeSeriesSplit(n_splits=4)

# Perform grid search with 5-fold cross-validation
xgb_grid_search = GridSearchCV(estimator=xgb_reg, param_grid=xgb_param_grid, scoring='neg_mean_squared_error', cv=tscv, verbose=1, n_jobs=-1)

xgb_grid_search.fit(features_train, target_train)

# Output the best parameters and RMSE score
print("Best parameters found: ", xgb_grid_search.best_params_)
# Out:
# Fitting 4 folds for each of 18 candidates, totalling 72 fits
# Best parameters found:  {'learning_rate': 0.12, 'max_depth': 4, 'n_estimators': 50}

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Same issue. Would you fix that?
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# Correct.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Student's comment </h2>
#
# Updated above.
#
# </div>

# %%
xgb_best_model = xgb_grid_search.best_estimator_

start_time = time.time()
xgb_best_model.fit(features_train, target_train)
xgb_fit_time = time.time() - start_time

xgb_target_predicted_valid = xgb_best_model.predict(features_valid)
rmse_valid = mean_squared_error(target_valid, xgb_target_predicted_valid, squared=False)

xgb_target_predicted_test = xgb_best_model.predict(features_test)
rmse_test = mean_squared_error(target_test, xgb_target_predicted_test, squared=False)

print(f"XGB RMSE Valid Score: {rmse_valid}")
print(f"XGB RMSE Test Score: {rmse_test}")
print(f"XGB Fit Time: {xgb_fit_time}")
# Out:
# XGB RMSE Valid Score: 33.85403320677181
# XGB RMSE Test Score: 52.963049536090196
# XGB Fit Time: 0.8326115608215332

# %%
pred_valid_df = pd.DataFrame(lgb_target_predicted_valid, index=target_valid.index)
pred_valid_df.rename(columns={0: 'Predictions'}, inplace=True)

pred_test_df = pd.DataFrame(lgb_target_predicted_test, index=target_test.index)
pred_test_df.rename(columns={0: 'Predictions'}, inplace=True)

# Plot the training predictions and actual values
ax1 = pred_valid_df.plot(label='Predictions')
target_valid.plot(ax=ax1, label='Actual')

# Display the legend for the first plot
ax1.legend()

# Plot the testing predictions and actual values
ax2 = pred_test_df.plot(label='Predictions')
target_test.plot(ax=ax2, label='Actual')

# Display the legend for the second plot
ax2.legend()

# Display the plots
plt.show()

# %% [markdown]
# Conclusion: Out of all the models with hyperparameters, the best of that performed on the training set was the Random Forest Model (32.77). The best that performed on the testing set was actually the LGBM model (42.5). Overall, the LGBM model is preferred due to the increase in speed of the training time on the datasets. On the jupyter notebook, the kernel session would die due to long processing times of the grid searches and finding the best hyperparameters of the models. With more resources, we can find better hyperparameters.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment</h2>
#
# Very good, thank you so much!
#
# </div>
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Please don't forget to update the conclusions.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# Excellent job, thank you!
# </div>

# %% [markdown]
# # Review checklist

# %% [markdown]
# - [x]  Jupyter Notebook is open
# - [ ]  The code is error-free
# - [ ]  The cells with the code have been arranged in order of execution
# - [ ]  The data has been downloaded and prepared
# - [ ]  The data has been analyzed
# - [ ]  The model has been trained and hyperparameters have been selected
# - [ ]  The models have been evaluated. Conclusion has been provided
# - [ ] *RMSE* for the test set is not more than 48
